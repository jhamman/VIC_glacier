# %%
import os
import re
import numpy as np
import pandas as pd

# %%
def read_vic_output(vicfile):
    header = {}
    with open(vicfile) as f:
        for i in xrange(6):
            s = f.readline()
            l = s.strip(' # ').strip('\n').split(': ', 1)
            if len(l) < 2:
                cols = l[0].strip(' ').split('\t')
                header['cols'] = [col.strip() for col in cols]
            else:
                header[l[0]] = l[1]
        df = pd.read_table(f, names=header['cols'], parse_dates=[[0, 1, 2]], index_col=0)
        df.index.name = 'date'
        return df

# %%
basedir = '../rainier/outputs/'
sims = ['vic.4.1.2.k_rainier',
        'vic.4.2.dev_rainier', 
        'vic.4.2.dev_glacier_off_rainier', 
        'vic.4.2.dev_scaling_on_rainier']
outfiles = ['fluxes_46.84375_-121.78125',
            'snow_46.84375_-121.78125',
            'snowband_46.84375_-121.78125']

# %%
data = {}
for sim in sims:
    for outfile in outfiles:
        vicfile = os.path.join(basedir, sim, outfile)
        if not os.path.exists(vicfile):
            vicfile += '.txt'
        df = read_vic_output(vicfile)     
        if sim in data:
            data[sim] = data[sim].join(df)
        else:
            data[sim] = df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-4617ebc7b230> in <module>()
#       7         df = read_vic_output(vicfile)
#       8         if sim in data:
# ----> 9             data[sim] = data[sim].join(df)
#      10         else:
#      11             data[sim] = df
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in join(self, other, on, how, lsuffix, rsuffix, sort)
#    3578         # For SparseDataFrame's benefit
#    3579         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 3580                                  rsuffix=rsuffix, sort=sort)
#    3581
#    3582     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    3592             return merge(self, other, left_on=on, how=how,
#    3593                          left_index=on is None, right_index=True,
# -> 3594                          suffixes=(lsuffix, rsuffix), sort=sort)
#    3595         else:
#    3596             if on is not None:
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/tools/merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy)
#      38                          right_index=right_index, sort=sort, suffixes=suffixes,
#      39                          copy=copy)
# ---> 40     return op.get_result()
#      41 if __debug__:
#      42     merge.__doc__ = _merge_doc % '\nleft : DataFrame'
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/tools/merge.pyc in get_result(self)
#     187
#     188         # this is a bit kludgy
# --> 189         ldata, rdata = self._get_merge_data()
#     190
#     191         # TODO: more efficiently handle group keys to avoid extra
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/tools/merge.pyc in _get_merge_data(self)
#     282         lsuf, rsuf = self.suffixes
#     283         ldata, rdata = ldata._maybe_rename_join(rdata, lsuf, rsuf,
# --> 284                                                 copydata=False)
#     285         return ldata, rdata
#     286
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/internals.pyc in _maybe_rename_join(self, other, lsuffix, rsuffix, copydata)
#    3441             if not lsuffix and not rsuffix:
#    3442                 raise ValueError('columns overlap but no suffix specified: %s'
# -> 3443                                  % to_rename)
#    3444
#    3445             def lrenamer(x):
#
# ValueError: columns overlap but no suffix specified: Index([u'OUT_SWE_BAND_0', u'OUT_SWE_BAND_1', u'OUT_SWE_BAND_2', u'OUT_SWE_BAND_3', u'OUT_SWE_BAND_4'], dtype='object')

# %%
f, axarr = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, figsize=(15, 10))
for i, sim in enumerate(sims):
    axind = np.unravel_index(i, axarr.shape)
    sca(axarr[axind])
#     data[sim]['OUT_SWE'].plot()
    for band in xrange(5):
        var = 'OUT_SWE_BAND_{band}'.format(band=band)
        data[sim][var]["1948-01-01":"1955-10-01"].plot()
    title(sim)
    ylabel('SWE (mm)')    
#     ylim([0, 10000])
    
sca(axarr[-1, -1])
legend(loc='center left', bbox_to_anchor=(1.5, .85))

# %%
sim = 'vic.4.2.dev_scaling_on_rainier'
outfile = 'glacier_46.84375_-121.78125.txt'
vicfile = os.path.join(basedir, sim, outfile)
df = read_vic_output(vicfile)
print df.keys()
# Out:
# Index([u'OUT_SWE', u'OUT_SNOW_MELT', u'OUT_SWE_BAND_0', u'OUT_SWE_BAND_1', u'OUT_SWE_BAND_2', u'OUT_SWE_BAND_3', u'OUT_SWE_BAND_4', u'OUT_IWE_BAND_0', u'OUT_IWE_BAND_1', u'OUT_IWE_BAND_2', u'OUT_IWE_BAND_3', u'OUT_IWE_BAND_4', u'OUT_BN_BAND_0', u'OUT_BN_BAND_1', u'OUT_BN_BAND_2', u'OUT_BN_BAND_3', u'OUT_BN_BAND_4', u'OUT_SNOW_DENSITY', u'OUT_SNOW_DENS_BAND_0', u'OUT_SNOW_DENS_BAND_1', u'OUT_SNOW_DENS_BAND_2', u'OUT_SNOW_DENS_BAND_3', u'OUT_SNOW_DENS_BAND_4'], dtype='object')

# %%
for band in xrange(5):
    var = 'OUT_SWE_BAND_{band}'.format(band=band)
    df[var]["1948-01-01":"1990-10-01"].plot()    
figure()
for band in xrange(5):
    var = 'OUT_SNOW_DENS_BAND_{band}'.format(band=band)
    df[var]["1948-01-01":"1949-10-01"].plot()
    
figure()
for band in xrange(5):
    var = 'OUT_IWE_BAND_{band}'.format(band=band)
    df[var]["1947-01-01":"1990-10-01"].plot()

figure()
for band in xrange(5):
    var = 'OUT_BN_BAND_{band}'.format(band=band)
    df[var]["1947-01-01":"1990-10-01"].plot()

# %%
df['OUT_SNOW_DENSITY']["1948-01-01":"1985-10-01"].plot()

# %%
df['OUT_IWE']["1948-01-01":"1985-10-01"].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-c572dc16addf> in <module>()
# ----> 1 df['OUT_IWE']["1948-01-01":"1985-10-01"].plot()
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1656             return self._getitem_multilevel(key)
#    1657         else:
# -> 1658             return self._getitem_column(key)
#    1659
#    1660     def _getitem_column(self, key):
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1663         # get column
#    1664         if self.columns.is_unique:
# -> 1665             return self._get_item_cache(key)
#    1666
#    1667         # duplicate columns & possible reduce dimensionaility
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1003         res = cache.get(item)
#    1004         if res is None:
# -> 1005             values = self._data.get(item)
#    1006             res = self._box_item_values(item, values)
#    1007             cache[item] = res
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item)
#    2871                 return self.get_for_nan_indexer(indexer)
#    2872
# -> 2873             _, block = self._find_block(item)
#    2874             return block.get(item)
#    2875         else:
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/internals.pyc in _find_block(self, item)
#    3183
#    3184     def _find_block(self, item):
# -> 3185         self._check_have(item)
#    3186         for i, block in enumerate(self.blocks):
#    3187             if item in block:
#
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/internals.pyc in _check_have(self, item)
#    3190     def _check_have(self, item):
#    3191         if item not in self.items:
# -> 3192             raise KeyError('no item named %s' % com.pprint_thing(item))
#    3193
#    3194     def reindex_axis(self, new_axis, indexer=None, method=None, axis=0,
#
# KeyError: u'no item named OUT_IWE'
